# %%
import pandas as pd 
import numpy as np

# %%
first = pd.read_csv("Revenue Chart.csv")
second = pd.read_csv("Revenue Chart-1.csv")
second
# Out:
#      Adjusted for Inflation Title  Adjusted for Inflation Notes  Year Date  \
# 0                             NaN                           NaN       1983
# 1                             NaN                           NaN       1984
# 2                             NaN                           NaN       1985
# 3                             NaN                           NaN       1986
# 4                             NaN                           NaN       1987
# 5                             NaN                           NaN       1988
# 6                             NaN                           NaN       1989
# 7                             NaN                           NaN       1990
# 8                             NaN                           NaN       1991
# 9                             NaN                           NaN       1992
# 10                            NaN                           NaN       1993
# ...
