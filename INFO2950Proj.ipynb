# %%
import pandas as pd 
import numpy as np
import re

# %%
first = pd.read_csv("Revenue Chart.csv")
second = pd.read_csv("Revenue Chart-1.csv")
third = pd.read_csv("movie_titles_metadata.txt", sep = '\[]')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-8-960cf7f845f1> in <module>
#       1 first = pd.read_csv("Revenue Chart.csv")
#       2 second = pd.read_csv("Revenue Chart-1.csv")
# ----> 3 third = pd.read_csv("movie_titles_metadata.txt", sep = '+++$+++', engine = 'python')
#
# ...
